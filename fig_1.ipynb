# %% [markdown]
# # Figure 1

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# Font sizes to use:
SMALLER_SIZE = 13
SMALL_SIZE = 14
MEDIUM_SIZE = 18
BIGGER_SIZE = 32

# General plot parameters:
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)    # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALLER_SIZE)  # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('xtick.major', size=10)
plt.rc('xtick', direction="inout")
plt.rc('ytick.major', size=10)
plt.rc('ytick', direction="inout")

def minor(a, e): # calculates semiminor axis
    return (math.sqrt(a**2 * (1 - e**2)))

def orbit(shaded_belt):
    plt.figure(figsize = (8,8), facecolor="white")
    ax = plt.gca()

    # Earth values:
    a = 1.0000010178  # semimajor axis [AU]
    e = 0.0167086     # eccentricity
    b = minor(a,e)    # semiminor axis [AU]

    # shading the main Asteroid Belt region:
    if shaded_belt == True:
        ellipse = Ellipse(xy=(0,0), width=6.4, height=6.4, edgecolor=None, fc="gray", alpha=0.15,
                          label="AB", zorder= 0)
        ax.add_patch(ellipse)
        ellipse = Ellipse(xy=(0,0), width=4, height=4, edgecolor=None, fc="white", label="AB", zorder= 1)
        ax.add_patch(ellipse)

    # Earth:
    ellipse = Ellipse(xy=(0,0), width=(2*a), height=(2*b), edgecolor='black', fc='None',
                      lw=linewid_r, label="Earth", zorder= 20)
    ax.add_patch(ellipse)

    # Mars:
    ellipse = Ellipse(xy=(0,0), width=(2*1.524), height=(2*minor(1.524, 0.0934)), edgecolor="black",
                      fc='None', alpha = 0.4, lw=linewid_r, label="Mars", zorder= 20)
    ax.add_patch(ellipse)

    # Ceres:
    ellipse = Ellipse(xy=(0,0), width=(2*2.76618), height=(2*minor(2.76618, 0.07789)), edgecolor=c_c,
                      fc='None', alpha = alph, ls = "dashed", lw=linewid, label="Ceres", zorder= 20)
    ax.add_patch(ellipse)
    
    # Pallas:
    ellipse = Ellipse(xy=(0,0), width=(2*2.77236), height=(2*minor(2.77236, 0.22965)), edgecolor=c_p,
                      fc='None', alpha = alph, ls = "dashed", lw=linewid, label="Pallas", zorder= 20)
    ax.add_patch(ellipse)

    # Vesta:
    ellipse = Ellipse(xy=(0,0), width=(2*2.36076), height=(2*minor(2.36076, 0.0903)), edgecolor=c_v,
                      fc='None', alpha = alph, ls = "dashed", lw=linewid, label="Vesta", zorder= 20)
    ax.add_patch(ellipse)

    # Hygeia:
    ellipse = Ellipse(xy=(0,0), width=(2*3.13687), height=(2*minor(3.13687, 0.11966)), edgecolor=c_h,
                      fc='None', alpha = alph, ls = "dashed", lw=linewid, label="Hygeia", zorder= 20)
    ax.add_patch(ellipse)

    # Jupiter:
    ellipse = Ellipse(xy=(0,0), width=(2*5.2038), height=(2*minor(5.2038, 0.0489)), edgecolor="black",
                      fc='None', alpha = 0.4, lw=linewid_r, label="Jupiter", zorder= 2)
    ax.add_patch(ellipse)

# Colors associated w/ Ceres, Pallas, Vesta, Hygeia, and Earth:
c_c = 'xkcd:bright sky blue'
c_p = 'xkcd:bright blue'
c_v = 'green'
c_h = 'yellowgreen'
c_e = 'black'

linewid_r = 2       # linewidth variable for real planets
linewid= 2          # linewidth variable for extra planet
alph = 1            # alpha variable for extra planet

# Call orbit plot function:
orbit(shaded_belt=True)

# Plot:
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title("Initial Solar System conditions")
plt.xlabel("x (AU)")
plt.ylabel("y (AU)")
plt.plot(0,0, color='black', marker = '*', markersize = 10) # Mark the Sun with a star
plt.grid(alpha = 0.4, zorder=5)

plt.legend(handles = [plt.plot([],ls="-", c='black', alpha=1)[0]] +
                     [plt.plot([],ls="-", c='black', alpha=0.4)[0]] + 
                     [plt.plot([],ls="--", lw=linewid, c=c_v)[0]] +
                     [plt.plot([],ls="--", lw=linewid, c=c_p)[0]] + 
                     [plt.plot([],ls="--", lw=linewid, c=c_c)[0]] + 
                     [plt.plot([],ls="--", lw=linewid, c=c_h)[0]] + 
                     [plt.plot([],ls="-", c='black', alpha=0.4)[0]] ,
           labels=["Earth", "Mars", "Vesta", "Pallas", "Ceres", "Hygeia", "Jupiter"],
           loc="upper right",
           handletextpad = 0.7,
           frameon=True,
           fancybox=True,
           framealpha=0.9)

plt.savefig('fig_1.png', dpi=300, bbox_inches="tight")
plt.show()
